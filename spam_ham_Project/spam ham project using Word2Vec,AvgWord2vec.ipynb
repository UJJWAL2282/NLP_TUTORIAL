# %%
# %pip install gensim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in c:\users\ujjwal\appdata\roaming\python\python313\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\ujjwal\appdata\roaming\python\python313\site-packages (from gensim) (2.3.3)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\ujjwal\appdata\roaming\python\python313\site-packages (from gensim) (1.16.2)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\ujjwal\appdata\roaming\python\python313\site-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in c:\users\ujjwal\appdata\roaming\python\python313\site-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gensim
from gensim.models import word2vec,keyedvectors

# %%
import gensim.downloader as api
wv=api.load('word2vec-google-news-300')

vec_king=wv['king']
